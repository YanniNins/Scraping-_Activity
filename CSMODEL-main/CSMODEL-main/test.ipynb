# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
Y  = [100000000000, 1000000000, 100000000, 100000000000]
X = [ 1, 2 , 3, 5]

# %%
plt.scatter(X, Y)

# %%
plt.scatter(X, np.log(Y))

# %%
X = np.random.standard_normal((10000))
print(X)
# Out:
# [0.06232762 0.78564373 0.85973036 ... 0.76249403 0.11339113 0.69383391]

# %%
plt.hist(X, bins=10)
# Out:
# (array([ 982., 1012., 1002., 1013.,  994.,  955., 1004.,  944., 1076.,
#         1018.]),
#  array([1.15240727e-04, 1.00102421e-01, 2.00089601e-01, 3.00076781e-01,
#         4.00063961e-01, 5.00051141e-01, 6.00038322e-01, 7.00025502e-01,
#         8.00012682e-01, 8.99999862e-01, 9.99987042e-01]),
#  <BarContainer object of 10 artists>)
